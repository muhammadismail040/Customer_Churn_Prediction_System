# %% [markdown]
# # Customer Churn Prediction & Recommendation System
#
# # Phase 8 – Model Evaluation
#
# ## Objectives
#
# - Evaluate the selected model
# - Generate classification report
# - Plot confusion matrix
# - Plot ROC Curve
# - Save the best model

# %% [markdown]
# ### Import Libraries

# %%
import warnings
warnings.filterwarnings("ignore")

import os
import joblib
import numpy as np
import matplotlib.pyplot as plt

from sklearn.metrics import (
    confusion_matrix,
    classification_report,
    ConfusionMatrixDisplay,
    RocCurveDisplay,
    roc_auc_score
)

# %% [markdown]
# ### Load saved pipeline

# %%
preprocessor = joblib.load("../models/preprocessors/preprocessing_pipeline.pkl")

target_encoder = joblib.load("../models/preprocessors/target_encoder.pkl")

# %% [markdown]
# ### Load dataset

# %%
import sys
sys.path.append("..")

from src.preprocessing.data_loader import load_data

df = load_data("../data/processed/Telco_Customer_Churn_Cleaned.csv")

df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %% [markdown]
# ### Prepared Data

# %%
from sklearn.model_selection import train_test_split

X = df.drop("Churn", axis=1)

y = target_encoder.transform(df["Churn"])

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

X_train = preprocessor.transform(X_train)
X_test = preprocessor.transform(X_test)

# %% [markdown]
# ### Train logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()

model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# ### Prediction

# %%
predictions = model.predict(X_test)

probabilities = model.predict_proba(X_test)[:,1]

# %% [markdown]
# ### classification report

# %%
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.89      0.87      1035
#            1       0.66      0.56      0.60       374
#
#     accuracy                           0.81      1409
#    macro avg       0.75      0.73      0.74      1409
# weighted avg       0.80      0.81      0.80      1409

# %% [markdown]
# ### Confusion Matrix

# %%
cm = confusion_matrix(y_test, predictions)

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=target_encoder.classes_
)

disp.plot(cmap="Blues")

plt.title("Confusion Matrix")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 cm = confusion_matrix(y_test, predictions)
#       2
#       3 disp = ConfusionMatrixDisplay(
#       4     confusion_matrix=cm,
#
# NameError: name 'confusion_matrix' is not defined

# %% [markdown]
# ### ROC Curve

# %%
RocCurveDisplay.from_predictions(
    y_test,
    probabilities
)

plt.title("ROC Curve")

plt.show()

# %% [markdown]
# ### ROC AUC Curve

# %%
auc = roc_auc_score(y_test, probabilities)

print("ROC AUC Score :", round(auc,4))
# Out:
# ROC AUC Score : 0.8419

# %% [markdown]
# ### Save the best Model

# %%
os.makedirs("../models/best_model", exist_ok=True)

joblib.dump(
    model,
    "../models/best_model/churn_prediction_model.pkl"
)

print("Best model saved successfully!")
# Out:
# Best model saved successfully!
