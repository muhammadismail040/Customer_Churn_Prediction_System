# %%
import os
import sys

project_root = os.path.abspath("..")
sys.path.insert(0, project_root)

print(project_root)
# Out:
# e:\ML Internship\Customer_Churn_Prediction_System

# %%
import os

os.makedirs("models/best_model", exist_ok=True)
os.makedirs("models/preprocessors", exist_ok=True)
os.makedirs("models/encoders", exist_ok=True)
os.makedirs("models/clustering", exist_ok=True)
os.makedirs("models/scalers", exist_ok=True)

# %%
import os

print(os.getcwd())
# Out:
# e:\ML Internship\Customer_Churn_Prediction_System\notebook

# %%
from src.api.model_loader import *

print(type(model))
print(type(preprocessor))
print(type(target_encoder))
print(type(kmeans_model))
print(type(scaler))
# Out:
# <class 'sklearn.linear_model._logistic.LogisticRegression'>
# <class 'sklearn.compose._column_transformer.ColumnTransformer'>
# <class 'sklearn.preprocessing._label.LabelEncoder'>
# <class 'sklearn.cluster._kmeans.KMeans'>
# <class 'sklearn.preprocessing._data.StandardScaler'>

# %%
from src.api.schemas import CustomerData

customer = CustomerData(
    gender="Female",
    SeniorCitizen=0,
    Partner="Yes",
    Dependents="No",
    tenure=12,
    PhoneService="Yes",
    MultipleLines="No",
    InternetService="Fiber optic",
    OnlineSecurity="No",
    OnlineBackup="Yes",
    DeviceProtection="No",
    TechSupport="No",
    StreamingTV="Yes",
    StreamingMovies="Yes",
    Contract="Month-to-month",
    PaperlessBilling="Yes",
    PaymentMethod="Electronic check",
    MonthlyCharges=79.5,
    TotalCharges=954.0
)

print(customer)
# Out:
# gender='Female' SeniorCitizen=0 Partner='Yes' Dependents='No' tenure=12 PhoneService='Yes' MultipleLines='No' InternetService='Fiber optic' OnlineSecurity='No' OnlineBackup='Yes' DeviceProtection='No' TechSupport='No' StreamingTV='Yes' StreamingMovies='Yes' Contract='Month-to-month' PaperlessBilling='Yes' PaymentMethod='Electronic check' MonthlyCharges=79.5 TotalCharges=954.0
